# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
import math
from Pedro_package import Pedro_Variable, Pedro_Function, Pedro_Parameter, Pedro_Layer, Pedro_Model
from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
import Pedro_package.functions as F
import Pedro_package.layer as L
from Pedro_package.models import Pedro_MLP
from Pedro_package import optimizers
from Pedro_package import datasets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f15477f7d8d8> in <cell line: 9>()
#       7 import matplotlib.pyplot as plt
#       8 import math
# ----> 9 from Pedro_package import Pedro_Variable, Pedro_Function, Pedro_Parameter, Pedro_Layer, Pedro_Model
#      10 from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
#      11 import Pedro_package.functions as F
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
x, t = datasets.get_spiral(train=True)
print(x.shape)
print(y.shape)

print(x[10], t[10])
print(x[110], t[110])

N, CLS_NUM = 100, 3
markers = ['o', 'x', '^']
colors = ['orange', 'blue', 'green']
for i in range(len(x)):
    c = t[i]
    plt.scatter(x[i][0], x[i][1], s=40, marker=markers[c], c=colors[c])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-600d09290ba2> in <cell line: 1>()
# ----> 1 x, t = datasets.get_spiral(train=True)
#       2 print(x.shape)
#       3 print(y.shape)
#       4
#       5 print(x[10], t[10])
#
# NameError: name 'datasets' is not defined

# %%
max_epoch = 300
batch_size = 30
hidden_size = 10
lr = 1.0

x, t = datasets.get_spiral(train=True)
model = Pedro_MLP((2, hidden_size, 3))
optimizer = optimizers.SGD(lr).setup(model)

data_size = len(x)
max_iter = math.ceil(data_size / batch_size)
avg_loss = np.zeros(max_epoch)

for epoch in range(max_epoch):
    index = np.random.permutation(data_size)
    sum_loss = 0

    for i in range(max_iter):
        batch_index = index[i * batch_size:(i + 1) * batch_size]
        batch_x = x[batch_index]
        batch_t = t[batch_index]

        y = model(batch_x)
        loss = F.softmax_cross_entropy(y, batch_t)
        model.cleargrads()
        loss.backward()
        optimizer.update()

        sum_loss += float(loss.data) * len(batch_t)

    avg_loss[epoch] = sum_loss / data_size
    print('epoch %d, loss %.2f' % (epoch + 1, avg_loss[epoch]))


plt.plot(np.arange(max_epoch), avg_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Loss Function')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bcb234c03a9f> in <cell line: 6>()
#       4 lr = 1.0
#       5
# ----> 6 x, t = datasets.get_spiral(train=True)
#       7 model = Pedro_MLP((2, hidden_size, 3))
#       8 optimizer = optimizers.SGD(lr).setup(model)
#
# NameError: name 'datasets' is not defined

# %%
from Pedro_package import no_grad

h = 0.001
x_min, x_max = x[:, 0].min() - .1, x[:, 0].max() + .1
y_min, y_max = x[:, 1].min() - .1, x[:, 1].max() + .1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
X = np.c_[xx.ravel(), yy.ravel()]

with no_grad():
    score = model(X)
predict_cls = np.argmax(score.data, axis=1)
Z = predict_cls.reshape(xx.shape)
plt.contourf(xx, yy, Z)


x, t = datasets.get_spiral(train=True)
print(x.shape)
print(t.shape)

print(x[10], t[10])
print(x[110], t[110])

N, CLS_NUM = 100, 3
markers = ['o', 'x', '^']
colors = ['orange', 'blue', 'green']
for i in range(len(x)):
    c = t[i]
    plt.scatter(x[i][0], x[i][1], s=40, marker=markers[c], c=colors[c])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-314fccc78328> in <cell line: 1>()
# ----> 1 from Pedro_package import no_grad
#       2
#       3 h = 0.001
#       4 x_min, x_max = x[:, 0].min() - .1, x[:, 0].max() + .1
#       5 y_min, y_max = x[:, 1].min() - .1, x[:, 1].max() + .1
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
