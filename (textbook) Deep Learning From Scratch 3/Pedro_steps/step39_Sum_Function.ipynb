# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
import math
from Pedro_package import Pedro_Variable, Pedro_Function
from Pedro_package.utils import get_dot_graph, plot_dot_graph
import Pedro_package.functions as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-543c63ef3415> in <cell line: 9>()
#       7 import matplotlib.pyplot as plt
#       8 import math
# ----> 9 from Pedro_package import Pedro_Variable, Pedro_Function
#      10 from Pedro_package.utils import get_dot_graph, plot_dot_graph
#      11 import Pedro_package.functions as F
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
x = Pedro_Variable(np.array([1, 2, 3, 4, 5, 6]))
y = F.sum(x)
y.backward()

print(y)
print(x.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-363120f1e14b> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.array([1, 2, 3, 4, 5, 6]))
#       2 y = F.sum(x)
#       3 y.backward()
#       4
#       5 print(y)
#
# NameError: name 'Pedro_Variable' is not defined

# %%
x = Pedro_Variable(np.array([[1, 2, 3],
                             [4, 5, 6]]))
y = F.sum(x)
y.backward()

print(y)
print(x.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4e60cbee6056> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.array([[1, 2, 3],
#       2                              [4, 5, 6]]))
#       3 y = F.sum(x)
#       4 y.backward()
#       5
#
# NameError: name 'Pedro_Variable' is not defined

# %%
x = np.array([[1, 2, 3],
              [4, 5, 6]])
y1 = np.sum(x, axis=0)
y2 = np.sum(x, axis=0, keepdims=True)
z1 = np.sum(x, axis=1)
z2 = np.sum(x, axis=1, keepdims=True)

print(y1)
print(x.shape, ' -> ', y1.shape)
print(y2)
print(x.shape, ' -> ', y2.shape)
print(z1)
print(x.shape, ' -> ', z1.shape)
print(z2)
print(x.shape, ' -> ', z2.shape)
# Out:
# [5 7 9]
# (2, 3)  ->  (3,)
# [[5 7 9]]
# (2, 3)  ->  (1, 3)
# [ 6 15]
# (2, 3)  ->  (2,)
# [[ 6]
#  [15]]
# (2, 3)  ->  (2, 1)

# %%
aa = Pedro_Variable(np.array([[1, 2, 3],
                              [4, 5, 6]]))
bb = F.sum(aa, axis=0)
bb.backward()

print(bb)
print(aa.grad)

aa = Pedro_Variable(np.random.randn(2, 3, 4, 5))
bb = aa.sum(keepdims=True)
print(bb.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2ac84e77d0a9> in <cell line: 1>()
# ----> 1 aa = Pedro_Variable(np.array([[1, 2, 3],
#       2                               [4, 5, 6]]))
#       3 bb = F.sum(aa, axis=0)
#       4 bb.backward()
#       5
#
# NameError: name 'Pedro_Variable' is not defined
