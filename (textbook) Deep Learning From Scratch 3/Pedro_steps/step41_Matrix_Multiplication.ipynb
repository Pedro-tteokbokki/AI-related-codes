# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
import math
from Pedro_package import Pedro_Variable, Pedro_Function
from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
import Pedro_package.functions as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2bc07d824557> in <cell line: 9>()
#       7 import matplotlib.pyplot as plt
#       8 import math
# ----> 9 from Pedro_package import Pedro_Variable, Pedro_Function
#      10 from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
#      11 import Pedro_package.functions as F
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = np.dot(a, b)
print(c)

d = np.array([[1, 2],
              [3, 4]])
e = np.array([[5, 6],
              [7, 8]])
f = np.dot(d, e)
print(f)
# Out:
# 32
# [[19 22]
#  [43 50]]

# %%
d * e
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %%
x = Pedro_Variable(np.random.randn(2, 3))
W = Pedro_Variable(np.random.randn(3, 4))
y = F.matmul(x, W)
y.backward()

print(y.shape)
print(x.grad.shape)
print(W.grad.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-83f3b38c63aa> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.random.randn(2, 3))
#       2 W = Pedro_Variable(np.random.randn(3, 4))
#       3 y = F.matmul(x, W)
#       4 y.backward()
#       5
#
# NameError: name 'Pedro_Variable' is not defined
