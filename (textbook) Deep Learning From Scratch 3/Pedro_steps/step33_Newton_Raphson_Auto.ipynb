# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from IPython.display import Image, display
import numpy as np
import math
from Pedro_package import Pedro_Variable, Pedro_Function
from Pedro_package.utils import get_dot_graph, plot_dot_graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-12197f5d1cf8> in <cell line: 8>()
#       6 import numpy as np
#       7 import math
# ----> 8 from Pedro_package import Pedro_Variable, Pedro_Function
#       9 from Pedro_package.utils import get_dot_graph, plot_dot_graph
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def f(x):
    y = x**4 - 2 * x**2
    return y

x = Pedro_Variable(np.array(2.0))
y = f(x)
y.backward(create_graph=True)
print(x.grad)

gx = x.grad
gx.backward()
print(x.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d588140589a0> in <cell line: 5>()
#       3     return y
#       4
# ----> 5 x = Pedro_Variable(np.array(2.0))
#       6 y = f(x)
#       7 y.backward(create_graph=True)
#
# NameError: name 'Pedro_Variable' is not defined

# %%
def f(x):
    y = x**4 - 2 * x**2
    return y

x = Pedro_Variable(np.array(2.0))
y = f(x)
y.backward(create_graph=True)
print(x.grad)

gx = x.grad
x.cleargrad()
gx.backward()
print(x.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ef0b2e27f967> in <cell line: 5>()
#       3     return y
#       4
# ----> 5 x = Pedro_Variable(np.array(2.0))
#       6 y = f(x)
#       7 y.backward(create_graph=True)
#
# NameError: name 'Pedro_Variable' is not defined

# %%
def f(x):
    y = x**4 - 2 * x**2
    return y

x = Pedro_Variable(np.array(2.0))
iters = 10

for i in range(iters):
    print(i, x)

    y = f(x)
    x.cleargrad()
    y.backward(create_graph=True)

    gx = x.grad
    x.cleargrad()
    gx.backward()
    gx2 = x.grad

    x.data -= gx.data / gx2.data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0f7ec20c5c2f> in <cell line: 5>()
#       3     return y
#       4
# ----> 5 x = Pedro_Variable(np.array(2.0))
#       6 iters = 10
#       7
#
# NameError: name 'Pedro_Variable' is not defined
