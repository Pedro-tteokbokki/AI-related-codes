# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import numpy as np
import matplotlib.pyplot as plt
import weakref
import contextlib
from Pedro_package.core import Pedro_Variable
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-eb943e023810> in <cell line: 9>()
#       7 import weakref
#       8 import contextlib
# ----> 9 from Pedro_package.core import Pedro_Variable
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
x = Pedro_Variable(np.array(1.0))
y = (x + 3) ** 2
y.backward()

print(y)
print(x.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-599ed4ebfe5f> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.array(1.0))
#       2 y = (x + 3) ** 2
#       3 y.backward()
#       4
#       5 print(y)
#
# NameError: name 'Pedro_Variable' is not defined
