# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
import math
from Pedro_package import Pedro_Variable, Pedro_Function
from Pedro_package.utils import get_dot_graph, plot_dot_graph
import Pedro_package.functions as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-543c63ef3415> in <cell line: 9>()
#       7 import matplotlib.pyplot as plt
#       8 import math
# ----> 9 from Pedro_package import Pedro_Variable, Pedro_Function
#      10 from Pedro_package.utils import get_dot_graph, plot_dot_graph
#      11 import Pedro_package.functions as F
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
x = np.array([[1, 2, 3],
              [4, 5, 6]])
y = np.reshape(x, (6, ))
z = x.reshape((6, ))
print(y)
print(z)
# Out:
# [1 2 3 4 5 6]
# [1 2 3 4 5 6]

# %%
aa = Pedro_Variable(np.array([[1, 2, 3],
                              [4, 5, 6]]))
bb = F.reshape(aa, (6, ))
bb.backward(retain_graph=True)

print(aa)
print(bb)
print(bb.grad)
print(aa.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b393e0ed0bda> in <cell line: 1>()
# ----> 1 aa = Pedro_Variable(np.array([[1, 2, 3],
#       2                               [4, 5, 6]]))
#       3 bb = F.reshape(aa, (6, ))
#       4 bb.backward(retain_graph=True)
#       5
#
# NameError: name 'Pedro_Variable' is not defined

# %%
x = np.random.rand(1, 2, 3)

y1 = x.reshape((2, 3))
y2 = x.reshape([2, 3])
y3 = x.reshape(2, 3)

print(y1)
print(y2)
print(y3)
# Out:
# [[0.31833177 0.64321383 0.26949521]
#  [0.43635936 0.4125047  0.13287413]]
# [[0.31833177 0.64321383 0.26949521]
#  [0.43635936 0.4125047  0.13287413]]
# [[0.31833177 0.64321383 0.26949521]
#  [0.43635936 0.4125047  0.13287413]]

# %%
x = Pedro_Variable(np.random.randn(1, 2, 3))

y1 = x.reshape((2, 3))
y2 = x.reshape([2, 3])
y3 = x.reshape(2, 3)

print(y1)
print(y2)
print(y3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1010899e3f24> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.random.randn(1, 2, 3))
#       2
#       3 y1 = x.reshape((2, 3))
#       4 y2 = x.reshape([2, 3])
#       5 y3 = x.reshape(2, 3)
#
# NameError: name 'Pedro_Variable' is not defined

# %%
x = np.array([[1, 2, 3],
              [4, 5, 6]])
y = x.transpose()

print(x)
print(y)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
aa = Pedro_Variable(np.array([[1, 2, 3],
                              [4, 5, 6]]))
bb = F.transpose(aa)
bb.backward(retain_graph=True)

print(aa)
print(bb)
print(bb.grad)
print(aa.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9d74e40eca8a> in <cell line: 1>()
# ----> 1 aa = Pedro_Variable(np.array([[1, 2, 3],
#       2                               [4, 5, 6]]))
#       3 bb = F.transpose(aa)
#       4 bb.backward(retain_graph=True)
#       5
#
# NameError: name 'Pedro_Variable' is not defined

# %%
aa = Pedro_Variable(np.array([[1, 2, 3],
                              [4, 5, 6]]))
bb = aa.transpose()
print(bb)
cc = aa.T
print(cc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2cac79e47ba8> in <cell line: 1>()
# ----> 1 aa = Pedro_Variable(np.array([[1, 2, 3],
#       2                               [4, 5, 6]]))
#       3 bb = aa.transpose()
#       4 print(bb)
#       5 cc = aa.T
#
# NameError: name 'Pedro_Variable' is not defined

# %%
A, B, C, D = 1, 2, 3, 4
x = np.random.rand(A, B, C, D)
y = x.transpose()
z = x.transpose(1, 0, 3, 2)

print(x)
print('=' * 50)
print(y)
print('=' * 50)
print(z)
# Out:
# [[[[0.2501103  0.87468871 0.94307772 0.53762147]
#    [0.80609755 0.27541785 0.92782878 0.60430607]
#    [0.32868076 0.9289837  0.36063559 0.74300285]]
#
#   [[0.58815102 0.48053308 0.07572209 0.92797601]
#    [0.98049858 0.27814212 0.56406903 0.98540781]
#    [0.63130771 0.86343307 0.59012648 0.06124855]]]]
# ==================================================
# [[[[0.2501103 ]
#    [0.58815102]]
#
#   [[0.80609755]
#    [0.98049858]]
#
#   [[0.32868076]
#    [0.63130771]]]
#
#
#  [[[0.87468871]
#    [0.48053308]]
#
#   [[0.27541785]
#    [0.27814212]]
#
#   [[0.9289837 ]
#    [0.86343307]]]
#
#
#  [[[0.94307772]
#    [0.07572209]]
#
#   [[0.92782878]
#    [0.56406903]]
#
#   [[0.36063559]
#    [0.59012648]]]
#
#
#  [[[0.53762147]
#    [0.92797601]]
#
#   [[0.60430607]
#    [0.98540781]]
#
#   [[0.74300285]
#    [0.06124855]]]]
# ==================================================
# [[[[0.2501103  0.80609755 0.32868076]
#    [0.87468871 0.27541785 0.9289837 ]
#    [0.94307772 0.92782878 0.36063559]
#    [0.53762147 0.60430607 0.74300285]]]
#
#
#  [[[0.58815102 0.98049858 0.63130771]
#    [0.48053308 0.27814212 0.86343307]
#    [0.07572209 0.56406903 0.59012648]
#    [0.92797601 0.98540781 0.06124855]]]]

# %%
A, B, C, D = 1, 2, 3, 4
x = Pedro_Variable(np.random.rand(A, B, C, D))
y = F.transpose(x, (1, 0, 3, 2))
y.backward(retain_grad=True)

print(x)
print('=' * 50)
print(y)
print('=' * 50)
print(y.grad)
print('=' * 50)
print(x.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-964fc744da98> in <cell line: 2>()
#       1 A, B, C, D = 1, 2, 3, 4
# ----> 2 x = Pedro_Variable(np.random.rand(A, B, C, D))
#       3 y = F.transpose(x, (1, 0, 3, 2))
#       4 y.backward(retain_grad=True)
#       5
#
# NameError: name 'Pedro_Variable' is not defined
