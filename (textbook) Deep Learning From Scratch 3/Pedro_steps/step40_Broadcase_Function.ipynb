# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
import math
from Pedro_package import Pedro_Variable, Pedro_Function
from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
import Pedro_package.functions as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2bc07d824557> in <cell line: 9>()
#       7 import matplotlib.pyplot as plt
#       8 import math
# ----> 9 from Pedro_package import Pedro_Variable, Pedro_Function
#      10 from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
#      11 import Pedro_package.functions as F
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
x = np.array([1, 2, 3])
y = np.broadcast_to(x, (2, 3))
print(y)
# Out:
# [[1 2 3]
#  [1 2 3]]

# %%
x = np.array([[1, 2, 3],
              [4, 5, 6]])
y = sum_to(x, (1, 3))
print(y)

z = sum_to(x, (2, 1))
print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b2e82d9a8062> in <cell line: 3>()
#       1 x = np.array([[1, 2, 3],
#       2               [4, 5, 6]])
# ----> 3 y = sum_to(x, (1, 3))
#       4 print(y)
#       5
#
# NameError: name 'sum_to' is not defined

# %%
x0 = Pedro_Variable(np.array([1, 2, 3]))
x1 = Pedro_Variable(np.array([10]))
y = x0 + x1
y.backward()

print(y)
print(x0.grad)
print(x1.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7d8df8b5ba6c> in <cell line: 1>()
# ----> 1 x0 = Pedro_Variable(np.array([1, 2, 3]))
#       2 x1 = Pedro_Variable(np.array([10]))
#       3 y = x0 + x1
#       4 y.backward()
#       5
#
# NameError: name 'Pedro_Variable' is not defined
