# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
import math
from Pedro_package import Pedro_Variable, Pedro_Function, Pedro_Parameter, Pedro_Layer, Pedro_Model
from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
import Pedro_package.functions as F
import Pedro_package.layer as L
from Pedro_package.models import Pedro_MLP
from Pedro_package import optimizers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ea6c75c5f121> in <cell line: 9>()
#       7 import matplotlib.pyplot as plt
#       8 import math
# ----> 9 from Pedro_package import Pedro_Variable, Pedro_Function, Pedro_Parameter, Pedro_Layer, Pedro_Model
#      10 from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
#      11 import Pedro_package.functions as F
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
x = Pedro_Variable(np.array([[1, 2, 3],
                             [4, 5, 6]]))
y = F.get_item(x, 1)
print(y)

y.backward()
print(x.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-22513e3274c0> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.array([[1, 2, 3],
#       2                              [4, 5, 6]]))
#       3 y = F.get_item(x, 1)
#       4 print(y)
#       5
#
# NameError: name 'Pedro_Variable' is not defined

# %%
x = Pedro_Variable(np.array([[1, 2, 3],
                             [4, 5, 6]]))
indices = np.array([0, 0, 1])
y = F.get_item(x, indices)
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bf8866705f8b> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.array([[1, 2, 3],
#       2                              [4, 5, 6]]))
#       3 indices = np.array([0, 0, 1])
#       4 y = F.get_item(x, indices)
#       5 print(y)
#
# NameError: name 'Pedro_Variable' is not defined

# %%
x = Pedro_Variable(np.array([[1, 2, 3],
                             [4, 5, 6]]))
y = x[1]
print(y)

y = x[:,2]
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-78bae04678de> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.array([[1, 2, 3],
#       2                              [4, 5, 6]]))
#       3 y = x[1]
#       4 print(y)
#       5
#
# NameError: name 'Pedro_Variable' is not defined

# %%
model = Pedro_MLP((10, 3))

x = np.array([[0.2, -0.4]])
y = model(x)
print(y)

x = np.array([[0.2, -0.4],
              [0.3, 0.5],
              [1.3, -3.2],
              [2.1, 0.3]])
y = model(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8b5ad6b31a82> in <cell line: 1>()
# ----> 1 model = Pedro_MLP((10, 3))
#       2
#       3 x = np.array([[0.2, -0.4]])
#       4 y = model(x)
#       5 print(y)
#
# NameError: name 'Pedro_MLP' is not defined

# %%
model = Pedro_MLP((10, 3))

x = Pedro_Variable(np.array([[0.2, -0.4]]))
y = model(x)
p = F.softmax_simple(y)
print(y)
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c92837ad920e> in <cell line: 1>()
# ----> 1 model = Pedro_MLP((10, 3))
#       2
#       3 x = Pedro_Variable(np.array([[0.2, -0.4]]))
#       4 y = model(x)
#       5 p = F.softmax_simple(y)
#
# NameError: name 'Pedro_MLP' is not defined

# %%
aa = np.random.rand(4, 4)
p = F.softmax_simple(aa)
print(aa)
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-538e279d2b0b> in <cell line: 2>()
#       1 aa = np.random.rand(4, 4)
# ----> 2 p = F.softmax_simple(aa)
#       3 print(aa)
#       4 print(p)
#
# NameError: name 'F' is not defined

# %%
x = np.array([[0.2, -0.4],
              [0.3, 0.5],
              [1.3, -3.2],
              [2.1, 0.3]])
t = np.array([2, 0, 1, 0])
y = model(x)
loss = F.softmax_cross_entropy_simple(y, t)
print(loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-96cd7ffb451a> in <cell line: 6>()
#       4               [2.1, 0.3]])
#       5 t = np.array([2, 0, 1, 0])
# ----> 6 y = model(x)
#       7 loss = F.softmax_cross_entropy_simple(y, t)
#       8 print(loss)
#
# NameError: name 'model' is not defined
