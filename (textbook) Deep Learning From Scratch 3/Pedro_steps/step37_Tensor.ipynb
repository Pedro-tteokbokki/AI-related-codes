# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
import math
from Pedro_package import Pedro_Variable, Pedro_Function
from Pedro_package.utils import get_dot_graph, plot_dot_graph
import Pedro_package.functions as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-543c63ef3415> in <cell line: 9>()
#       7 import matplotlib.pyplot as plt
#       8 import math
# ----> 9 from Pedro_package import Pedro_Variable, Pedro_Function
#      10 from Pedro_package.utils import get_dot_graph, plot_dot_graph
#      11 import Pedro_package.functions as F
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
x = Pedro_Variable(np.array(1.0))
y = F.sin(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4c706e63f3b0> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.array(1.0))
#       2 y = F.sin(x)
#       3 print(y)
#
# NameError: name 'Pedro_Variable' is not defined

# %%
x = Pedro_Variable(np.array([[1, 2, 3],
                             [4, 5, 6]]))
y = F.sin(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e2ff43043745> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.array([[1, 2, 3],
#       2                              [4, 5, 6]]))
#       3 y = F.sin(x)
#       4 print(y)
#
# NameError: name 'Pedro_Variable' is not defined

# %%
x = Pedro_Variable(np.array([[1, 2, 3],
                             [4, 5, 6]]))
c = Pedro_Variable(np.array([[10, 20, 30],
                             [40, 50, 60]]))
t = x + c
print(t)

y = F.sum(t)
print(y)

y.backward(retain_grad=True)
print(y.grad)
print(t.grad)
print(x.grad)
print(c.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-066700198a0a> in <cell line: 1>()
# ----> 1 x = Pedro_Variable(np.array([[1, 2, 3],
#       2                              [4, 5, 6]]))
#       3 c = Pedro_Variable(np.array([[10, 20, 30],
#       4                              [40, 50, 60]]))
#       5 t = x + c
#
# NameError: name 'Pedro_Variable' is not defined
