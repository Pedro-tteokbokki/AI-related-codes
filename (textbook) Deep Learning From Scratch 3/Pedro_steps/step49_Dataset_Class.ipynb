# %%
import os, sys
ppp = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
import math
from Pedro_package import Pedro_Variable, Pedro_Function, Pedro_Parameter, Pedro_Layer, Pedro_Model
from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
import Pedro_package.functions as F
import Pedro_package.layer as L
from Pedro_package.models import Pedro_MLP
from Pedro_package import optimizers
from Pedro_package import datasets
from Pedro_package import transforms
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-31d6e09f9721> in <cell line: 9>()
#       7 import matplotlib.pyplot as plt
#       8 import math
# ----> 9 from Pedro_package import Pedro_Variable, Pedro_Function, Pedro_Parameter, Pedro_Layer, Pedro_Model
#      10 from Pedro_package.utils import get_dot_graph, plot_dot_graph, sum_to
#      11 import Pedro_package.functions as F
#
# ModuleNotFoundError: No module named 'Pedro_package'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
train_set = datasets.Spiral(train=True)
print(train_set[0])
print(len(train_set))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2814e351189a> in <cell line: 1>()
# ----> 1 train_set = datasets.Spiral(train=True)
#       2 print(train_set[0])
#       3 print(len(train_set))
#
# NameError: name 'datasets' is not defined

# %%
batch_index = [0, 1, 2]
batch = [train_set[i] for i in batch_index]
print(batch)

x = np.array([example[0] for example in batch])
t = np.array([example[1] for example in batch])
print(x.shape)
print(t.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3eedd48dc434> in <cell line: 2>()
#       1 batch_index = [0, 1, 2]
# ----> 2 batch = [train_set[i] for i in batch_index]
#       3 print(batch)
#       4
#       5 x = np.array([example[0] for example in batch])
#
# <ipython-input-3-3eedd48dc434> in <listcomp>(.0)
#       1 batch_index = [0, 1, 2]
# ----> 2 batch = [train_set[i] for i in batch_index]
#       3 print(batch)
#       4
#       5 x = np.array([example[0] for example in batch])
#
# NameError: name 'train_set' is not defined

# %%
max_epoch = 300
batch_size = 30
hidden_size = 10
lr = 1.0

train_set = datasets.Spiral()
model = Pedro_MLP((hidden_size, 3))
optimizer = optimizers.SGD(lr).setup(model)

data_size = len(train_set)
max_iter = math.ceil(data_size / batch_size)
avg_loss = np.zeros(max_epoch)

for epoch in range(max_epoch):
    index = np.random.permutation(data_size)
    sum_loss = 0

    for i in range(max_iter):
        batch_index = index[i*batch_size:(i+1)*batch_size]
        batch = [train_set[i] for i in batch_index]
        batch_x = np.array([example[0] for example in batch])
        batch_t = np.array([example[1] for example in batch])

        y = model(batch_x)
        loss = F.softmax_cross_entropy(y, batch_t)
        model.cleargrads()
        loss.backward()
        optimizer.update()

        sum_loss += float(loss.data) * len(batch_t)

    avg_loss[epoch] = sum_loss / data_size
    print('epoch %d, loss %.2f' % (epoch+1, avg_loss[epoch]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d1c6e036f164> in <cell line: 6>()
#       4 lr = 1.0
#       5
# ----> 6 train_set = datasets.Spiral()
#       7 model = Pedro_MLP((hidden_size, 3))
#       8 optimizer = optimizers.SGD(lr).setup(model)
#
# NameError: name 'datasets' is not defined

# %%
train_set = datasets.Spiral()
print(train_set[0])

def f(x):
    y = x / 2.0
    return y

train_set = datasets.Spiral(transform=f, target_transform=lambda x: 5*x)
print(train_set[0])

g = transforms.Normalize(mean=0.0, std=2.0)
train_set = datasets.Spiral(transform=g)
print(train_set[0])

k = transform.Compose([transform.Normalize(mean=0.0, std=2.0),
                       transforms.AsType(np.float64)])
train_set = datasets.Spiral(transform=k)
print(train_set[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-123d8c7e1ab3> in <cell line: 1>()
# ----> 1 train_set = datasets.Spiral()
#       2 print(train_set[0])
#       3
#       4 def f(x):
#       5     y = x / 2.0
#
# NameError: name 'datasets' is not defined
