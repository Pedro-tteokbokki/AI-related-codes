# %%
# !pip install graphviz

# %%
# !dot -V
# Out:
# dot - graphviz version 2.43.0 (0)

# %%
# %%writefile sample25.dot
#
# digraph g{
#     x
#     y
# }
# Out:
# Writing sample25.dot

# %%
# !dot sample25.dot -T png -o sample25.png

# %%
# %pycat sample25.dot

# %%
from IPython.display import Image, display
Image(filename='sample25.png')

# %%
# %%writefile sample25.dot
#
# digraph g{
# 1 [label="x", color=orange, style=filled]
# 2 [label="y", color=blue, style=filled]
# }
# Out:
# Overwriting sample25.dot

# %%
# !dot sample25.dot -T png -o sample25.png
Image(filename='sample25.png')

# %%
# %%writefile sample25.dot
#
# digraph g{
# 1 [label="x", color=orange, style=filled]
# 2 [label="y", color=blue, style=filled]
# 3 [label="Exp", color=red, style=filled]
# }
# Out:
# Overwriting sample25.dot

# %%
# !dot sample25.dot -T png -o sample25.png
Image(filename='sample25.png')

# %%
# %%writefile sample25.dot
#
# digraph g{
# 1 [label="x", color=orange, style=filled]
# 2 [label="y", color=blue, style=filled]
# 3 [label="Exp", color=red, style=filled]
# 1 -> 3
# 2 -> 3
# }
# Out:
# Overwriting sample25.dot

# %%
# !dot sample25.dot -T png -o sample25.png
Image(filename='sample25.png')

# %%
from graphviz import Digraph

dot = Digraph(comment='The Round Table')

dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedeverse the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

dot
